# %% [markdown]
# # Policy Chat: NL(x) and LLM - Evaluation of Results
#
# This notebook reads in the output from the three models:
# 1. LLaMA7B (w/ and w/out prompt engineering)
# 2. LLaMA7B Chat (w/ and w/out prompt engineering)
# 3. Finetuned LLaMA7B
#
# And **calculates automatic text generation metrics. Specifically, we use Hugging Face modules and calculate:**
# 1. **Bleu** score
# 2. **Meteor** score
# 3. **Rouge 1-gram, bigram and L** scores
#
# ## Prompt Engineering Evaluation:
# After calculating the Bleu/Meteor/Rouge scores for all the various prompt engineering techniques on the two base LLaMA models, we plot their scores against each other to determine what the best prompt engineering technique is. **We determine that no prompt engineering is the best prompt engineering technique**, at least according to automated metrics. This is true for both the vanilla LLaMA7B model and the chat version, although the specific comparisons vary between the two.
#
# ## Finetuning evaluation:
# To assess the value of finetuning, we calculate the automated metrics on the finetuned model (no prompt engineering) and then graph it in comparison to the average prompt engineering scores as well as the base models without prompt engineering. **We determine that finetuning LLaMA7B drastically outperforms the base models with and without prompt engineering**, often by a factor of 2x or more.
#
# ## Human Evaluation:
# We collected human evaluation of output on a small subsample of the predictions for each model as well. The tabulation of this data is in an excel file located elsewhere in the repository. The broad implications of the human evaluation correlate highly with the automated metrics. One small discrepancy is that **the human evaluation show that one-shot and few-shot prompting techniques are more effective than no prompt engineering**, although the differences are small and not highly reliable due to the small sample size.

# %% [markdown]
# ## Set Up:
#
# - load packages
# - read in dataset

# %%
# !pip install transformers datasets -q
# !pip install accelerate -U -q
# !pip install rouge_score -q
# !pip install langchain  -q
# !pip install sentencepiece  -q
# !pip install bitsandbytes  -q
# !pip install transformers  -q
# !pip install evaluate -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for rouge_score (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.0/817.0 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 29.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.4/252.4 kB 25.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 17.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 1.4 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')


# Import libraries
from datasets import (
    load_dataset,
    load_metric
)
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    Trainer,
    TrainingArguments,
    pipeline,
    BitsAndBytesConfig
)
import evaluate
from transformers.pipelines.pt_utils import KeyDataset

from sklearn.model_selection import train_test_split

import torch
import accelerate
import pandas as pd
import os



# HF Info
HF_TOKEN = "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"
MODEL_NAME_CHAT = 'meta-llama/Llama-2-7b-chat-hf'
MODEL_NAME_BASE = 'meta-llama/Llama-2-7b-hf'

# Directories
data_dir = '/content/drive/MyDrive/NLX/'
output_dir = '/content/drive/MyDrive/NLX/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Read in data

# %%
# Read in data
custom_datapath = os.path.join( data_dir, "finetune-dataset.csv" )

dataset = pd.read_csv( custom_datapath)
dataset
# Out:
#      prompt_technique                                           question  \
# 0            prompt_0                 What does the EU AI Act stand for?
# 1            prompt_1  \n    Give the most concise answers possible t...
# 2            prompt_2  \n    Give an answer to my query by modeling t...
# 3            prompt_3  \n    Give an answer to my query by modeling t...
# 4            prompt_4  \n    First, analyze the keywords in the query...
# ...               ...                                                ...
# 2497         prompt_1  \n    Give the most concise answers possible t...
# 2498         prompt_2  \n    Give an answer to my query by modeling t...
# 2499         prompt_3  \n    Give an answer to my query by modeling t...
# 2500         prompt_4  \n    First, analyze the keywords in the query...
# 2501         prompt_5  \n    Think of 3 possible different answers to...
#
#                                                  answer  \
# 0      Proposal for a Regulation laying down harmoni...
# 1      Proposal for a Regulation laying down harmoni...
# 2      Proposal for a Regulation laying down harmoni...
# 3      Proposal for a Regulation laying down harmoni...
# 4      Proposal for a Regulation laying down harmoni...
# ...                                                 ...
# 2497  The policy outlines a schedule for declassifyi...
# 2498  The policy outlines a schedule for declassifyi...
# 2499  The policy outlines a schedule for declassifyi...
# 2500  The policy outlines a schedule for declassifyi...
# 2501  The policy outlines a schedule for declassifyi...
#
#                                              train_text  \
# 0     Question:\n What does the EU AI Act stand for?...
# 1     Question:\n\n    Give the most concise answers...
# 2     Question:\n\n    Give an answer to my query by...
# 3     Question:\n\n    Give an answer to my query by...
# 4     Question:\n\n    First, analyze the keywords i...
# ...                                                 ...
# 2497  Question:\n\n    Give the most concise answers...
# 2498  Question:\n\n    Give an answer to my query by...
# 2499  Question:\n\n    Give an answer to my query by...
# 2500  Question:\n\n    First, analyze the keywords i...
# 2501  Question:\n\n    Think of 3 possible different...
#
#                                               test_text
# 0     Question:\n What does the EU AI Act stand for?...
# 1     Question:\n\n    Give the most concise answers...
# 2     Question:\n\n    Give an answer to my query by...
# 3     Question:\n\n    Give an answer to my query by...
# 4     Question:\n\n    First, analyze the keywords i...
# ...                                                 ...
# 2497  Question:\n\n    Give the most concise answers...
# 2498  Question:\n\n    Give an answer to my query by...
# 2499  Question:\n\n    Give an answer to my query by...
# 2500  Question:\n\n    First, analyze the keywords i...
# 2501  Question:\n\n    Think of 3 possible different...
#
# [2502 rows x 5 columns]

# %%
dataset.loc[1, 'train_text']
# Out:
# 'Question:\n\n    Give the most concise answers possible to questions about AI policy, considering you are an expert of AI policy. \n\n     What does the EU AI Act stand for?\n\nAnswer:\n Proposal for a Regulation laying down harmonized rules for artificial intelligence.'

# %%
dataset.loc[1, 'test_text']
# Out:
# 'Question:\n\n    Give the most concise answers possible to questions about AI policy, considering you are an expert of AI policy. \n\n     What does the EU AI Act stand for?\n\nAnswer:\n'

# %%
# Turn dataset into a HF dataset class
from datasets import Dataset
dataset_hf = Dataset.from_dict( dataset.to_dict(orient='list') )
dataset_hf[0]['question']
# Out:
# ' What does the EU AI Act stand for?'

# %% [markdown]
# # 0. Prompt Engineering Evaluation
#
# See how prompt engineering affected scores from automated metrics for:
# 1. Vanilla LLaMA7B
# 2. Chat LLaMA7B

# %% [markdown]
# ---
#
# # Read in output from models
#
# ### 1. Read in LLaMA7B output (w and w/out prompt engineering)

# %%
# Read in model outputs
vanilla_output = pd.read_csv(os.path.join(data_dir, 'LLaMA7B-predictions.csv') ).drop('Unnamed: 0', axis=1)
vanilla_output.head(2)
# Out:
#      model         prompting  \
# 0  LLaMA7B      No Prompting
# 1  LLaMA7B  Task instruction
#
#                                             question  \
# 0  What are some possible benefits of the widespr...
# 1  What are some possible benefits of the widespr...
#
#                                         ground_truth  \
# 0  The widespread adoption and use of Generative ...
# 1  The widespread adoption and use of Generative ...
#
#                                           prediction
# 0  What are some possible benefits of the widespr...
# 1  Give the most concise answers possible to ques...

# %% [markdown]
# ### 1. Read in Chat model output (w and w/out prompt engineering)

# %%
chat_output = pd.read_csv(os.path.join(data_dir, 'LLaMA7B-chat-predictions.csv') ).drop('Unnamed: 0', axis=1)
chat_output.head(2)
# Out:
#           model         prompting  \
# 0  LLaMA7B-chat      No Prompting
# 1  LLaMA7B-chat  Task instruction
#
#                                             question  \
# 0  What are some possible benefits of the widespr...
# 1  What are some possible benefits of the widespr...
#
#                                         ground_truth  \
# 0  The widespread adoption and use of Generative ...
# 1  The widespread adoption and use of Generative ...
#
#                                           prediction
# 0  What are some possible benefits of the widespr...
# 1  Give the most concise answers possible to ques...

# %% [markdown]
# ### 1. Concatenate chat and vanilla model output together

# %%
model_output = pd.concat([vanilla_output, chat_output])
model_output['used_prompting'] = 'Used Prompting'
model_output.loc[ model_output['prompting']=='No Prompting', 'used_prompting'] = 'No Prompting'
model_output.head(2)
# Out:
#      model         prompting  \
# 0  LLaMA7B      No Prompting
# 1  LLaMA7B  Task instruction
#
#                                             question  \
# 0  What are some possible benefits of the widespr...
# 1  What are some possible benefits of the widespr...
#
#                                         ground_truth  \
# 0  The widespread adoption and use of Generative ...
# 1  The widespread adoption and use of Generative ...
#
#                                           prediction  used_prompting
# 0  What are some possible benefits of the widespr...    No Prompting
# 1  Give the most concise answers possible to ques...  Used Prompting

# %% [markdown]
# ## 2. Clean model output to get ready for automated evaluation pipeline
# - Strip out the question from the model answer so we can directly compare ground truth answer to model answer
#
# #### Dataset cleaning function:

# %%
# Strip out question from answer
# Function to find the index of the question string in the prediction string
def find_index(row):
    index = row['prediction'].find(row['question'])
    return index

# Function to extract text after the index found
def extract_text(row):
    index = row['index']
    if index != -1:
        return row['prediction'][index + len(row['question']):]
    else:
        return ''

# Applying the functions to create the new column
model_output['index'] = model_output.apply(find_index, axis=1)
model_output['prediction_answer_only'] = model_output.apply(extract_text, axis=1)

# Dropping the temporary 'index' column
model_output.drop(columns=['index'], inplace=True)

model_output
# Out:
#             model           prompting  \
# 0         LLaMA7B        No Prompting
# 1         LLaMA7B    Task instruction
# 2         LLaMA7B  One-shot prompting
# 3         LLaMA7B  Few-shot prompting
# 4         LLaMA7B     Prompt chaining
# ..            ...                 ...
# 499  LLaMA7B-chat    Task instruction
# 500  LLaMA7B-chat  One-shot prompting
# 501  LLaMA7B-chat  Few-shot prompting
# 502  LLaMA7B-chat     Prompt chaining
# 503  LLaMA7B-chat    Active prompting
#
#                                               question  \
# 0    What are some possible benefits of the widespr...
# 1    What are some possible benefits of the widespr...
# 2    What are some possible benefits of the widespr...
# 3    What are some possible benefits of the widespr...
# 4    What are some possible benefits of the widespr...
# ..                                                 ...
# 499               Do you own your own image in the UK?
# 500               Do you own your own image in the UK?
# 501               Do you own your own image in the UK?
# 502               Do you own your own image in the UK?
# 503               Do you own your own image in the UK?
#
#                                           ground_truth  \
# 0    The widespread adoption and use of Generative ...
# 1    The widespread adoption and use of Generative ...
# 2    The widespread adoption and use of Generative ...
# 3    The widespread adoption and use of Generative ...
# 4    The widespread adoption and use of Generative ...
# ..                                                 ...
# 499  No, in the UK, there is no specific legal righ...
# 500  No, in the UK, there is no specific legal righ...
# 501  No, in the UK, there is no specific legal righ...
# 502  No, in the UK, there is no specific legal righ...
# 503  No, in the UK, there is no specific legal righ...
#
#                                             prediction  used_prompting  \
# 0    What are some possible benefits of the widespr...    No Prompting
# 1    Give the most concise answers possible to ques...  Used Prompting
# 2    Give an answer to my query by modeling the fol...  Used Prompting
# 3    Give an answer to my query by modeling the fol...  Used Prompting
# 4    First, analyze the keywords in the query. Seco...  Used Prompting
# ..                                                 ...             ...
# 499  Give the most concise answers possible to ques...  Used Prompting
# 500  Give an answer to my query by modeling the fol...  Used Prompting
# 501  Give an answer to my query by modeling the fol...  Used Prompting
# 502  First, analyze the keywords in the query. Seco...  Used Prompting
# 503  Think of 3 possible different answers to the q...  Used Prompting
#
#                                 prediction_answer_only
# 0             \nWhat could be a few potential downs...
# 1                                         (20)  15%[4]
# 2     Support your claims using concrete examples f...
# 3     How might these changes affect our lives?.   ...
# 4     Is there anything we could do that would make...
# ..                                                 ...
# 499   If so how do I claim it back from Google and ...
# 500     In this case I am referring specifically to...
# 501   Yes according tp th eData Prot ction actin o ...
# 502   If so which one are they and why did it take ...
# 503   If so who took it without asking permission f...
#
# [1008 rows x 7 columns]

# %% [markdown]
# ---
# # 3. Calculate automated metrics for:
# - Vanilla LLaMA7B (w and w/out prompt engineering)
# -  LLaMA7B chat (w and w/out prompt engineering)

# %%
# Calculate scores
meteor = evaluate.load('meteor')
bleu = evaluate.load('bleu')
rouge = evaluate.load('rouge')
# Out:
# Downloading builder script:   0%|          | 0.00/6.93k [00:00<?, ?B/s]
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# Downloading builder script:   0%|          | 0.00/5.94k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.34k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]

# %%
techniques = model_output['prompting'].unique()
models = model_output['model'].unique()

scores = []
for t in techniques:
  for m in models:
    subset =  model_output.loc[ (model_output['prompting'] == t) & (model_output['model'] == m), :  ]
    bscore = bleu.compute(  references = list(subset['ground_truth']) , predictions = list(subset['prediction_answer_only'] )  )
    mscore = meteor.compute(  references = list(subset['ground_truth']) , predictions = list(subset['prediction_answer_only']) )
    rscore = rouge.compute(  references = list(subset['ground_truth']) , predictions = list(subset['prediction_answer_only']) )
    scores.append( {'prompting': t, 'model':m, 'bleu_score':bscore['bleu'], 'meteor_score':mscore['meteor'],
                    'rouge_unigram_score':rscore['rouge1'],  'rouge_biigram_score':rscore['rouge2'],
                    'rouge_long_sequence_score':rscore['rougeL']} )

scores_df = pd.DataFrame(scores)
scores_df
# Out:
#              prompting         model  bleu_score  meteor_score  \
# 0         No Prompting       LLaMA7B    0.000000      0.104659
# 1         No Prompting  LLaMA7B-chat    0.000000      0.099100
# 2     Task instruction       LLaMA7B    0.000000      0.077544
# 3     Task instruction  LLaMA7B-chat    0.000000      0.053843
# 4   One-shot prompting       LLaMA7B    0.000000      0.046380
# 5   One-shot prompting  LLaMA7B-chat    0.000000      0.041680
# 6   Few-shot prompting       LLaMA7B    0.024598      0.056832
# 7   Few-shot prompting  LLaMA7B-chat    0.025394      0.064984
# 8      Prompt chaining       LLaMA7B    0.000000      0.074109
# 9      Prompt chaining  LLaMA7B-chat    0.000000      0.064771
# 10    Active prompting       LLaMA7B    0.000000      0.055047
# 11    Active prompting  LLaMA7B-chat    0.000000      0.015219
#
#     rouge_unigram_score  rouge_biigram_score  rouge_long_sequence_score
# 0              0.113963             0.006370                   0.077710
# 1              0.110890             0.008924                   0.077840
# 2              0.086703             0.003888                   0.054159
# 3              0.069179             0.004462                   0.050546
# 4              0.045696             0.001375                   0.032737
# 5              0.040506             0.000807                   0.029651
# 6              0.051168             0.007201                   0.038579
# 7              0.061928             0.009764                   0.043470
# 8              0.078811             0.002906                   0.051950
# 9              0.071198             0.001945                   0.049421
# 10             0.053543             0.001625                   0.036768
# 11             0.015338             0.001087                   0.011803

# %% [markdown]
# ### Save scores

# %%
# Save to output
scores_df.to_csv( os.path.join(output_dir, 'automated_metrics_llama7b_vanilla_and_chat.csv'))

# %% [markdown]
# # 4. Plot the automated metrics scores for LLaMA7B vanilla

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Melt the DataFrame to long format
df_melted = pd.melt(scores_df.loc[scores_df['model'] == 'LLaMA7B', :].drop('model', axis=1), id_vars='prompting', var_name='metric', value_name='score')

# Determine the order for each prompting type within each metric
order_within_hue = df_melted.groupby(['metric', 'prompting'])['score'].mean().unstack().mean().sort_values().index

# Create grouped bar plot with ascending order for bars within each group and specified hue order
plt.figure(figsize=(10, 6))
sns.barplot(x='metric', y='score', hue='prompting', data=df_melted, hue_order=order_within_hue, order=df_melted['metric'].unique())
plt.title('Automated Metrics - Vanilla LLaMA7B w/ and w/out Prompting')
plt.xlabel('Metric')
plt.ylabel('Score')
plt.legend(title='Prompting')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 4. Plot scores for chat model

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Melt the DataFrame to long format
df_melted = pd.melt(scores_df.loc[scores_df['model'] == 'LLaMA7B-chat'].drop('model', axis=1), id_vars='prompting', var_name='metric', value_name='score')

# Determine the order for each prompting type within each metric
order_within_hue = df_melted.groupby(['metric', 'prompting'])['score'].mean().unstack().mean().sort_values().index

# Create grouped bar plot with ascending order for bars within each group
plt.figure(figsize=(10, 6))
sns.barplot(x='metric', y='score', hue='prompting', data=df_melted, hue_order=order_within_hue)
plt.title('Automated Metrics - Vanilla LLaMA7B-chat w/ and w/out Prompting')
plt.xlabel('Metric')
plt.ylabel('Score')
plt.legend(title='Prompting')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ---
# # 5.Fine tuning evaluation
#
# - read in output
# - Cleans dataset and seperates into 5 model categories:
# 1. Finetuned
# 2. Vanilla w/out prompt engineering
# 3. Chat w/out prompt engineering
# 4. Vanilla w prompt engineering
# 5. Chat w prompt engineering

# %%
# Scores on finetuned datasets
finetuned_earlier = pd.read_csv(os.path.join(data_dir, 'predictions.csv') )

# Applying the functions to create the new column
finetuned_earlier['index'] = finetuned_earlier.apply(find_index, axis=1)
finetuned_earlier['prediction_answer_only'] = finetuned_earlier.apply(extract_text, axis=1)

# Dropping the temporary 'index' column
finetuned_earlier.drop(columns=['index'], inplace=True)

# Create used_prompting column
finetuned_earlier['used_prompting'] = 'No Prompting'

finetuned_earlier['model'] = 'LLaMA7B-Chat-Finetuned'

finetuned_earlier.head(2)
# Out:
#                     model                                           question  \
# 0  LLaMA7B-Chat-Finetuned  What are some possible benefits of the widespr...
# 1  LLaMA7B-Chat-Finetuned  What are some recommendations for the governme...
#
#                                         ground_truth  \
# 0  The widespread adoption and use of Generative ...
# 1  Foster the sharing of AI knowledge internation...
#
#                                           prediction  \
# 0  What are some possible benefits of the widespr...
# 1  What are some recommendations for the governme...
#
#                               prediction_answer_only used_prompting
# 0  \n "The widespread adoption and use of Generat...   No Prompting
# 1  \nnational AI strategies should include polici...   No Prompting

# %%
model_output_all = pd.concat( [model_output, finetuned_earlier]).reset_index(drop=True)
model_output_all.sample(4)
# Out:
#                        model prompting  \
# 1008  LLaMA7B-Chat-Finetuned       NaN
# 1009  LLaMA7B-Chat-Finetuned       NaN
# 1010  LLaMA7B-Chat-Finetuned       NaN
# 1011  LLaMA7B-Chat-Finetuned       NaN
# 1012  LLaMA7B-Chat-Finetuned       NaN
# 1013  LLaMA7B-Chat-Finetuned       NaN
# 1014  LLaMA7B-Chat-Finetuned       NaN
# 1015  LLaMA7B-Chat-Finetuned       NaN
# 1016  LLaMA7B-Chat-Finetuned       NaN
# 1017  LLaMA7B-Chat-Finetuned       NaN
#
#                                                question  \
# 1008  What are some possible benefits of the widespr...
# 1009  What are some recommendations for the governme...
# 1010      What is the primary purpose of the EU AI Act?
# 1011   What is the potential global significance of ...
# 1012  Who were the featured speakers at the 2023 NAI...
# 1013  How are states and municipalities addressing g...
# 1014  What challenges do China's AI regulations pose...
# 1015  What are the three exceptions(AI systems) that...
# 1016   How does the inclusion of law enforcement in ...
# 1017  In which instances can the UN act as the arbit...
#
#                                            ground_truth  \
# 1008  The widespread adoption and use of Generative ...
# 1009  Foster the sharing of AI knowledge internation...
# 1010   The EU AI Act aims to regulate the sale and u...
# 1011   The article suggests that the week's AI polic...
# 1012  The Honorable Denis McDonough, Secretary of Ve...
# 1013  States and municipalities are actively legisla...
# 1014  Ensuring compliance with detailed regulatory r...
# 1015  AI systems exclusively developed or used for m...
# 1016   The White House's Blueprint excludes law enfo...
# 1017  Challenges to international security -  help e...
#
#                                              prediction used_prompting  \
# 1008  What are some possible benefits of the widespr...   No Prompting
# 1009  What are some recommendations for the governme...   No Prompting
# 1010   What is the primary purpose of the EU AI Act?...   No Prompting
# 1011   What is the potential global significance of ...   No Prompting
# 1012  Who were the featured speakers at the 2023 NAI...   No Prompting
# 1013  How are states and municipalities addressing g...   No Prompting
# 1014  What challenges do China's AI regulations pose...   No Prompting
# 1015  What are the three exceptions(AI systems) that...   No Prompting
# 1016   How does the inclusion of law enforcement in ...   No Prompting
# 1017  In which instances can the UN act as the arbit...   No Prompting
#
#                                  prediction_answer_only
# 1008  \n "The widespread adoption and use of Generat...
# 1009  \nnational AI strategies should include polici...
# 1010  \n  The primary purpose of the EU AI Act is to...
# 1011   The article suggests that the week's AI polic...
# 1012  \n A featured speaker at the 2023 NAII Interna...
# 1013  \nЉеаѕеѕ, they are implementing their own AI r...
# 1014  \n.\nThe challenges faced by AI developers in ...
# 1015  \nգ(1) systems whose core function is to ensur...
# 1016  \nЪ What are the main differences between the ...
# 1017  \nЋ The UN can act as the arbiter of AI govern...

# %% [markdown]
# # 6. Calculate automated metrics for finetuned and 4 other models

# %%
models = model_output_all['model'].unique()
prompt_techniques =  model_output_all['used_prompting'].unique()

scores = []
for t in prompt_techniques:
  for m in models:
      subset =  model_output_all.loc[ (model_output_all['model'] == m) &  (model_output_all['used_prompting'] == t) , :  ]
      if subset.shape[0] >0:
        bscore = bleu.compute(  references = list(subset['ground_truth']) , predictions = list(subset['prediction_answer_only'] )  )
        mscore = meteor.compute(  references = list(subset['ground_truth']) , predictions = list(subset['prediction_answer_only']) )
        rscore = rouge.compute(  references = list(subset['ground_truth']) , predictions = list(subset['prediction_answer_only']) )
        scores.append( { 'model':m, 'prompting':t, 'bleu_score':bscore['bleu'], 'meteor_score':mscore['meteor'],
                        'rouge_unigram_score':rscore['rouge1'],  'rouge_biigram_score':rscore['rouge2'],
                        'rouge_long_sequence_score':rscore['rougeL']} )

scores_finetuned_df = pd.DataFrame(scores)
scores_finetuned_df
# Out:
#                     model       prompting  bleu_score  meteor_score  \
# 0                 LLaMA7B    No Prompting    0.000000      0.104659
# 1            LLaMA7B-chat    No Prompting    0.000000      0.099100
# 2  LLaMA7B-Chat-Finetuned    No Prompting    0.046707      0.249685
# 3                 LLaMA7B  Used Prompting    0.007367      0.061983
# 4            LLaMA7B-chat  Used Prompting    0.007339      0.048099
#
#    rouge_unigram_score  rouge_biigram_score  rouge_long_sequence_score
# 0             0.113963             0.006370                   0.077710
# 1             0.110890             0.008924                   0.077840
# 2             0.274497             0.091353                   0.195507
# 3             0.063232             0.003399                   0.042795
# 4             0.051924             0.003670                   0.037180

# %%
scores_finetuned_df['model_prompting_type'] = scores_finetuned_df['model'] + ' - ' + scores_finetuned_df['prompting']
scores_finetuned_df.loc[ scores_finetuned_df['model_prompting_type'] == 'LLaMA7B-Chat-Finetuned - No Prompting', 'model_prompting_type'] = 'LLaMA7B-Chat - Finetuned'
scores_finetuned_df
# Out:
#                     model       prompting  bleu_score  meteor_score  \
# 0                 LLaMA7B    No Prompting    0.000000      0.104659
# 1            LLaMA7B-chat    No Prompting    0.000000      0.099100
# 2  LLaMA7B-Chat-Finetuned    No Prompting    0.046707      0.249685
# 3                 LLaMA7B  Used Prompting    0.007367      0.061983
# 4            LLaMA7B-chat  Used Prompting    0.007339      0.048099
#
#    rouge_unigram_score  rouge_biigram_score  rouge_long_sequence_score  \
# 0             0.113963             0.006370                   0.077710
# 1             0.110890             0.008924                   0.077840
# 2             0.274497             0.091353                   0.195507
# 3             0.063232             0.003399                   0.042795
# 4             0.051924             0.003670                   0.037180
#
#             model_prompting_type
# 0         LLaMA7B - No Prompting
# 1    LLaMA7B-chat - No Prompting
# 2       LLaMA7B-Chat - Finetuned
# 3       LLaMA7B - Used Prompting
# 4  LLaMA7B-chat - Used Prompting

# %% [markdown]
# # 7. Graph the results

# %%
# Melt the DataFrame to long format
df_melted = pd.melt(scores_finetuned_df.drop(['model', 'prompting'], axis=1), id_vars='model_prompting_type', var_name='metric', value_name='score')
df_melted
# Out:
#              model_prompting_type                     metric     score
# 0          LLaMA7B - No Prompting                 bleu_score  0.000000
# 1     LLaMA7B-chat - No Prompting                 bleu_score  0.000000
# 2        LLaMA7B-Chat - Finetuned                 bleu_score  0.046707
# 3        LLaMA7B - Used Prompting                 bleu_score  0.007367
# 4   LLaMA7B-chat - Used Prompting                 bleu_score  0.007339
# 5          LLaMA7B - No Prompting               meteor_score  0.104659
# 6     LLaMA7B-chat - No Prompting               meteor_score  0.099100
# 7        LLaMA7B-Chat - Finetuned               meteor_score  0.249685
# 8        LLaMA7B - Used Prompting               meteor_score  0.061983
# 9   LLaMA7B-chat - Used Prompting               meteor_score  0.048099
# 10         LLaMA7B - No Prompting        rouge_unigram_score  0.113963
# 11    LLaMA7B-chat - No Prompting        rouge_unigram_score  0.110890
# 12       LLaMA7B-Chat - Finetuned        rouge_unigram_score  0.274497
# 13       LLaMA7B - Used Prompting        rouge_unigram_score  0.063232
# 14  LLaMA7B-chat - Used Prompting        rouge_unigram_score  0.051924
# 15         LLaMA7B - No Prompting        rouge_biigram_score  0.006370
# 16    LLaMA7B-chat - No Prompting        rouge_biigram_score  0.008924
# 17       LLaMA7B-Chat - Finetuned        rouge_biigram_score  0.091353
# 18       LLaMA7B - Used Prompting        rouge_biigram_score  0.003399
# 19  LLaMA7B-chat - Used Prompting        rouge_biigram_score  0.003670
# 20         LLaMA7B - No Prompting  rouge_long_sequence_score  0.077710
# 21    LLaMA7B-chat - No Prompting  rouge_long_sequence_score  0.077840
# 22       LLaMA7B-Chat - Finetuned  rouge_long_sequence_score  0.195507
# 23       LLaMA7B - Used Prompting  rouge_long_sequence_score  0.042795
# 24  LLaMA7B-chat - Used Prompting  rouge_long_sequence_score  0.037180

# %%
# Determine the order for each model_prompting_type within each metric
order_within_hue = df_melted.groupby(['metric', 'model_prompting_type'])['score'].mean().unstack().mean().sort_values().index

# Create grouped bar plot with ascending order for bars within each group
plt.figure(figsize=(15, 6))
sns.barplot(x='metric', y='score', hue='model_prompting_type', data=df_melted, hue_order=order_within_hue)
plt.title('Average Automated Scores Across Models / Prompting')
plt.xlabel('Metric')
plt.ylabel('Score')
plt.legend(title='Model / Prompting')

# Tilt x-axis labels by 45 degrees
plt.xticks(rotation=0)

plt.show()
